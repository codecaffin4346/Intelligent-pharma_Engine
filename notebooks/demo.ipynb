# %% [markdown]
# # Intelligent Pharma-Context Engine Demo
# This notebook demonstrates the end-to-end pipeline for pharmaceutical record extraction, verification, and enrichment.

# %%
import sys
sys.path.append('..')
from src.pipeline import PharmaPipeline
import matplotlib.pyplot as plt
import cv2
import json

# %% [markdown]
# ## 1. Initialize Pipeline

# %%
pipeline = PharmaPipeline()
print("Pipeline initialized.")

# %% [markdown]
# ## 2. Process an Image
# Provide a path to a medicine bottle image.

# %%
image_path = '../data/sample_bottle.jpg' # Replace with actual path
try:
    result = pipeline.process_image(image_path)
    print(json.dumps(result, indent=2))
except Exception as e:
    print(f"Error: {e}")
